# %%
import pandas as pd

# %%
df = pd.read_csv('notebooks_nulos_exercicio.csv')

# %%
df.head()
# Out:
#     marca     ano  qtd_nucleos  qtd_threads  ram gpu_dedicada  ram_gpu
# 0  xiaomi     NaN           10           17   16          não      0.0  \
# 1    dell  2014.0            4            5   16          sim      6.0
# 2   razer  2016.0           12           18   32          sim      6.0
# 3  xiaomi  2023.0           10           20    8          não      0.0
# 4    asus  2018.0            4            5    6          não      0.0
#
#    entradas_usb  duracao_bateria resolucao_tela tipo_tela tela_touch
# 0           NaN            402.0         FULLHD      OLED        não  \
# 1           1.0            104.0         FULLHD      OLED        não
# 2           4.0             87.0         QUADHD    AMOLED        não
# 3           NaN            457.0             4K    AMOLED        não
# 4           NaN            359.0             HD        VA        não
#
#    armazenamento_hdd  armazenamento_ssd       segmento  valor
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   marca              10000 non-null  object
#  1   ano                9722 non-null   float64
#  2   qtd_nucleos        10000 non-null  int64
#  3   qtd_threads        10000 non-null  int64
#  4   ram                10000 non-null  int64
#  5   gpu_dedicada       10000 non-null  object
#  6   ram_gpu            8439 non-null   float64
#  7   entradas_usb       6071 non-null   float64
#  8   duracao_bateria    7568 non-null   float64
#  9   resolucao_tela     10000 non-null  object
#  10  tipo_tela          8879 non-null   object
#  11  tela_touch         10000 non-null  object
#  12  armazenamento_hdd  8876 non-null   float64
#  13  armazenamento_ssd  9930 non-null   float64
#  14  segmento           9054 non-null   object
#  15  valor              10000 non-null  int64
# ...
